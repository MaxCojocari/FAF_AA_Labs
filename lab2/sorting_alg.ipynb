# %%
import matplotlib.pyplot as plt
import numpy as np
import time as t
import math
import random
from prettytable import PrettyTable

# %%
arr = []
max = 1000001
for i in range(1000000):
  arr.append(random.randint(-max, max))

# %%
arr
# Out:
# [540146,
#  657735,
#  920874,
#  143671,
#  833822,
#  -537780,
#  -646339,
#  267470,
#  -757977,
#  -484980,
#  148871,
#  -656280,
#  85692,
#  -658072,
#  -769733,
#  -601503,
#  -587659,
#  144050,
#  -365162,
#  308708,
#  864647,
#  -52002,
#  -934282,
#  213047,
#  -644191,
#  557078,
#  -594803,
#  488509,
#  -312019,
#  820858,
#  121837,
#  -510842,
#  -286880,
#  297981,
#  -429274,
#  880482,
#  -442030,
#  722834,
#  -256260,
#  -639908,
#  95649,
#  742535,
#  821704,
#  -392969,
#  -715767,
#  347446,
#  741602,
#  791748,
#  79989,
#  -493057,
#  -468196,
#  -190317,
#  768412,
#  -475588,
#  -82344,
#  -313271,
#  278674,
#  767257,
#  -125335,
#  -717221,
#  -998546,
#  -56438,
#  957539,
#  -359052,
#  -60107,
#  -720961,
#  349625,
#  -746582,
#  -917711,
#  644166,
#  -432844,
#  -671679,
#  188590,
#  -882886,
#  -715569,
#  -499064,
#  -231000,
#  -876144,
#  -796173,
#  88781,
#  816241,
#  -16258,
#  232482,
#  -759032,
#  368271,
#  -52763,
#  -123495,
#  303869,
#  47761,
#  -636299,
#  667528,
#  -59762,
#  -892036,
#  938063,
#  -50399,
#  -766466,
#  -573295,
#  -374476,
#  -518523,
#  769876,
#  5367,
#  -65140,
#  235704,
#  -77593,
#  173648,
#  532322,
#  -713942,
#  503389,
#  179895,
#  -601708,
#  -910340,
#  867840,
#  -830441,
#  241215,
#  465709,
#  552342,
#  -397137,
#  462477,
#  -301827,
#  600565,
#  391959,
#  116312,
#  868904,
#  -933148,
#  569879,
#  887421,
#  123213,
#  786710,
#  503200,
#  835200,
#  623242,
#  -317811,
#  411911,
#  -440487,
#  434163,
#  -672389,
#  774878,
#  400767,
#  -974929,
#  -241240,
#  -648574,
#  186168,
#  -870923,
#  611700,
#  -262904,
#  -673843,
#  909075,
#  748755,
#  -675684,
#  -392093,
#  725972,
#  -690014,
#  -453396,
#  533242,
#  -412561,
#  790860,
#  381934,
#  -434210,
#  840221,
#  -226171,
#  268480,
#  -488534,
#  -665477,
#  -734330,
#  269404,
#  454044,
#  -686459,
#  -218971,
#  717478,
#  -243569,
#  839233,
#  -8462,
#  -914903,
#  123726,
#  -878303,
#  -947333,
#  -773648,
#  -948260,
#  524862,
#  251986,
#  -289840,
#  450207,
#  -613029,
#  777043,
#  -373835,
#  -981413,
#  81918,
#  481942,
#  -904869,
#  -88641,
#  785263,
#  -777613,
#  230880,
#  318178,
#  -85592,
#  -512223,
#  -450569,
#  -917970,
#  591205,
#  -816451,
#  723663,
#  -25172,
#  377198,
#  65507,
#  -978349,
#  -474560,
#  -654505,
#  -38230,
#  973416,
#  812455,
#  -301937,
#  401276,
#  -580578,
#  846166,
#  -519237,
#  7434,
#  703103,
#  145148,
#  342883,
#  253586,
#  665110,
#  -724268,
#  677288,
#  -67090,
#  543092,
#  547949,
#  -213096,
#  467401,
#  -300928,
#  828673,
#  -452812,
#  287579,
#  557463,
#  -151058,
#  -462856,
#  901812,
#  -702672,
#  221386,
#  -25199,
#  -156062,
#  -91963,
#  695148,
#  -988536,
#  311199,
#  84141,
#  655767,
#  -512022,
#  -546712,
#  -669343,
#  235583,
#  826024,
#  828158,
#  781384,
#  -972636,
#  84831,
#  972736,
#  234967,
#  784965,
#  -340249,
#  -759407,
#  -816702,
#  -587480,
#  852850,
#  239462,
#  161925,
#  -471772,
#  348820,
#  987508,
#  174664,
#  -698660,
#  686270,
#  -945008,
#  578950,
#  -301885,
#  979214,
#  982301,
#  -142882,
#  420617,
#  212228,
#  -740261,
#  551995,
#  -368833,
#  -547537,
#  972073,
#  -341507,
#  235808,
#  940309,
#  929815,
#  727001,
#  430382,
#  -982975,
#  828096,
#  -391389,
#  873981,
#  673340,
#  -398101,
#  -818522,
#  -543968,
#  566100,
#  -641667,
#  -339630,
#  621762,
#  979885,
#  -327828,
#  286329,
#  -438495,
#  277078,
#  811332,
#  -524364,
#  -927146,
#  59497,
#  -189289,
#  500446,
#  -804246,
#  704365,
#  -165562,
#  74385,
#  211566,
#  -6601,
#  -190381,
#  591652,
#  853024,
#  302504,
#  -173044,
#  -84065,
#  389209,
#  -544668,
#  -230112,
#  428616,
#  -115549,
#  597210,
#  -102715,
#  -548754,
#  794944,
#  845266,
#  -775723,
#  -240755,
#  654172,
#  -106721,
#  845020,
#  246142,
#  -274403,
#  81715,
#  224498,
#  264690,
#  430904,
#  528716,
#  -697367,
#  -864260,
#  830137,
#  330214,
#  911863,
#  -143002,
#  -1911,
#  -633813,
#  135497,
#  466985,
#  832004,
#  669337,
#  688672,
#  -861702,
#  988843,
#  -810088,
#  962611,
#  -631133,
#  -216405,
#  -783115,
#  -973600,
#  -661254,
#  -74418,
#  613164,
#  242394,
#  -26784,
#  -623287,
#  719008,
#  343244,
#  -99806,
#  -867827,
#  960803,
#  740428,
#  403519,
#  942670,
#  719414,
#  -875397,
#  -504062,
#  214403,
#  621371,
#  987478,
#  -884584,
#  -141393,
#  266161,
#  874554,
#  -125911,
#  -172894,
#  263469,
#  -104839,
#  410736,
#  -525556,
#  -757177,
#  -651502,
#  -875018,
#  186909,
#  -168937,
#  -904109,
#  66340,
#  -846819,
#  207084,
#  273693,
#  -959112,
#  809472,
#  -379689,
#  -895169,
#  -831352,
#  -812519,
#  -262925,
#  -354076,
#  -325206,
#  637943,
#  70190,
#  -202666,
#  -754042,
#  587657,
#  -421345,
#  81213,
#  26367,
#  846017,
#  197250,
#  -47196,
#  620678,
#  761469,
#  -37278,
#  -186002,
#  -461977,
#  -815369,
#  -158853,
#  -68874,
#  -682180,
#  958089,
#  374413,
#  -369406,
#  473484,
#  784279,
#  -111883,
#  268121,
#  -568100,
#  714731,
#  -374082,
#  571183,
#  -293540,
#  -451185,
#  410476,
#  -107239,
#  278471,
#  450703,
#  -241914,
#  92797,
#  -274296,
#  155567,
#  -87055,
#  -705702,
#  300869,
#  -321060,
#  574064,
#  194750,
#  -999592,
#  -859683,
#  -594151,
#  -190955,
#  328570,
#  -265069,
#  936039,
#  -737438,
#  993601,
#  -583394,
#  481746,
#  -400878,
#  196947,
#  115667,
#  122414,
#  553327,
#  453727,
#  788658,
#  722845,
#  -209131,
#  2545,
#  494383,
#  992284,
#  -236458,
#  -760855,
#  98045,
#  -194612,
#  -924351,
#  -795309,
#  25262,
#  659596,
#  -268504,
#  -382477,
#  -353231,
#  -488526,
#  -89270,
#  859205,
#  -49492,
#  -941292,
#  673380,
#  940880,
#  276974,
#  -919728,
#  -542100,
#  580776,
#  -226113,
#  -895718,
#  -562761,
#  959833,
#  481978,
#  -370952,
#  386972,
#  -228539,
#  -348304,
#  -156684,
#  219743,
#  218496,
#  -834907,
#  -680165,
#  -521790,
#  -634467,
#  -865964,
#  256020,
#  -812116,
#  -51157,
#  -148594,
#  162481,
#  615287,
#  -906171,
#  499988,
#  600365,
#  -238746,
#  -480760,
#  843625,
#  -161547,
#  -334718,
#  -325870,
#  555934,
#  335756,
#  631711,
#  269039,
#  -190552,
#  870548,
#  -890345,
#  -87098,
#  -423031,
#  -726571,
#  198048,
#  566948,
#  -13171,
#  -828532,
#  -697663,
#  354126,
#  -45627,
#  -24961,
#  -92651,
#  -245722,
#  -867910,
#  -657104,
#  -430603,
#  -525785,
#  -922457,
#  647927,
#  280484,
#  -694128,
#  -154164,
#  -883773,
#  743887,
#  91462,
#  421852,
#  -81306,
#  478358,
#  -338917,
#  -8627,
#  -441627,
#  -995910,
#  899959,
#  730344,
#  609894,
#  872050,
#  -903355,
#  974279,
#  -8051,
#  682905,
#  -843004,
#  -115572,
#  -828978,
#  -27729,
#  -317790,
#  884141,
#  -378371,
#  657804,
#  -103863,
#  575516,
#  -899648,
#  778289,
#  -636476,
#  -666126,
#  -494045,
#  -23846,
#  707170,
#  -924616,
#  213079,
#  779878,
#  719413,
#  625889,
#  -64493,
#  -854370,
#  -18279,
#  83874,
#  -897934,
#  830378,
#  -646303,
#  984254,
#  -283338,
#  885983,
#  372442,
#  124700,
#  -42850,
#  -320840,
#  -553741,
#  -98739,
#  156564,
#  864341,
#  287538,
#  -355243,
#  328015,
#  -260404,
#  176760,
#  295939,
#  47469,
#  684279,
#  272969,
#  -948960,
#  637262,
#  -201870,
#  -530621,
#  -987824,
#  123931,
#  347388,
#  -359331,
#  508970,
#  270773,
#  -906950,
#  -345627,
#  -419781,
#  78444,
#  53506,
#  471710,
#  -147407,
#  806702,
#  214466,
#  -834374,
#  896094,
#  -696479,
#  728971,
#  671423,
#  -462993,
#  -16524,
#  376455,
#  439463,
#  -356974,
#  37017,
#  63875,
#  25454,
#  -50163,
#  456555,
#  249154,
#  804340,
#  463471,
#  243465,
#  -537462,
#  288995,
#  -865109,
#  715445,
#  -335041,
#  -386171,
#  -4271,
#  -65441,
#  -619421,
#  -666186,
#  245002,
#  -510632,
#  -643563,
#  704154,
#  -235184,
#  142849,
#  -588609,
#  686243,
#  40151,
#  -886409,
#  450260,
#  403959,
#  -653611,
#  -900673,
#  -738590,
#  486223,
#  -185006,
#  427085,
#  -853524,
#  706797,
#  -458442,
#  767476,
#  -447299,
#  -261270,
#  21808,
#  -963755,
#  -806562,
#  -29165,
#  341835,
#  -237143,
#  121958,
#  -966009,
#  429305,
#  558971,
#  589100,
#  -113828,
#  820668,
#  145660,
#  822100,
#  9970,
#  625865,
#  -510866,
#  -602360,
#  -680709,
#  -618598,
#  -665210,
#  515897,
#  513003,
#  402938,
#  -83040,
#  -383498,
#  703870,
#  -893179,
#  260428,
#  -869370,
#  -112751,
#  -432243,
#  966529,
#  -555653,
#  -115344,
#  -249122,
#  -490705,
#  -882490,
#  -150871,
#  -330362,
#  -726909,
#  318320,
#  -579128,
#  -772716,
#  -149699,
#  -999409,
#  360977,
#  -993787,
#  217567,
#  -440761,
#  756727,
#  109116,
#  786708,
#  -91099,
#  -995161,
#  728459,
#  -616605,
#  463152,
#  -190120,
#  -829222,
#  -465565,
#  -755270,
#  3629,
#  143241,
#  839949,
#  -472986,
#  599914,
#  656206,
#  124231,
#  254180,
#  -663299,
#  473408,
#  -738756,
#  -791581,
#  -185469,
#  -202980,
#  477928,
#  -474062,
#  795137,
#  -17800,
#  -230963,
#  653911,
#  219962,
#  107312,
#  426543,
#  -184440,
#  -334579,
#  811025,
#  444421,
#  257893,
#  173288,
#  475769,
#  -817967,
#  632168,
#  -882657,
#  987095,
#  -141743,
#  465421,
#  -837359,
#  109791,
#  866079,
#  -24864,
#  296657,
#  -668252,
#  760725,
#  742525,
#  415537,
#  450132,
#  369935,
#  24932,
#  856992,
#  -625361,
#  -375395,
#  857244,
#  763449,
#  462675,
#  930872,
#  889103,
#  222674,
#  -493791,
#  118207,
#  -56832,
#  687080,
#  -119218,
#  -609391,
#  -197842,
#  494747,
#  424452,
#  581924,
#  795551,
#  -990678,
#  -479529,
#  -819366,
#  519090,
#  -573942,
#  -978644,
#  450837,
#  -563219,
#  -428765,
#  -119732,
#  257714,
#  983417,
#  -344583,
#  587224,
#  363079,
#  -989424,
#  -393969,
#  -532439,
#  -212281,
#  429711,
#  299021,
#  393157,
#  701973,
#  -156478,
#  232872,
#  -49230,
#  252996,
#  863402,
#  225743,
#  620250,
#  -124966,
#  -476006,
#  -981833,
#  -616649,
#  518926,
#  279118,
#  -230607,
#  -310833,
#  533639,
#  -688751,
#  -398163,
#  513918,
#  -135225,
#  808536,
#  -132243,
#  -340552,
#  -405489,
#  579,
#  -391325,
#  -550421,
#  281644,
#  -314450,
#  -634746,
#  -618565,
#  -505864,
#  718658,
#  644368,
#  -740587,
#  175479,
#  920922,
#  791138,
#  -409122,
#  -915924,
#  871622,
#  -290090,
#  -576407,
#  472978,
#  327283,
#  267177,
#  440831,
#  -285678,
#  -638199,
#  -688845,
#  -990397,
#  -797582,
#  132415,
#  -795244,
#  -348421,
#  -611450,
#  -233157,
#  -413555,
#  487561,
#  -746571,
#  -115011,
#  304415,
#  542046,
#  -934319,
#  -737589,
#  -719266,
#  -715497,
#  408467,
#  68428,
#  609034,
#  -757170,
#  -800108,
#  -264417,
#  824903,
#  182679,
#  -50235,
#  810265,
#  614432,
#  871450,
#  -946257,
#  -542468,
#  515392,
#  218978,
#  -398161,
#  492033,
#  72552,
#  -853607,
#  -204065,
#  632411,
#  377594,
#  -902415,
#  853248,
#  387675,
#  -231995,
#  582993,
#  -498583,
#  -802591,
#  -948687,
#  652842,
#  -930424,
#  -114425,
#  749892,
#  55735,
#  658319,
#  492062,
#  -355251,
#  816829,
#  128277,
#  783862,
#  -139097,
#  915935,
#  -707744,
#  -412130,
#  -619486,
#  -595718,
#  704639,
#  965600,
#  -187175,
#  537347,
#  275382,
#  -381907,
#  476512,
#  -278779,
#  279185,
#  -934781,
#  -290245,
#  900433,
#  -489153,
#  949707,
#  568602,
#  -580222,
#  428655,
#  948267,
#  -309184,
#  102839,
#  -361011,
#  218907,
#  ...]

# %%
def quick_sort(arr: list) -> list:
    """
    An implementation of Quicksort sorting algorithm.
    """
    if len(arr) <= 1:
        return arr
    else:
        pivot = arr[0]
        left = []
        right = []
        for i in arr[1:]:
            if i < pivot:
                left.append(i)
            else:
                right.append(i)
        return quick_sort(left) + [pivot] + quick_sort(right)

# %%
quick_sort([12, 4, 1, 7, 7, 1, 3])
# Out:
# [1, 1, 3, 4, 7, 7, 12]

# %%
def merge_sort(arr: list) -> list:
    """
    An implementation of Merge Sort sorting algorithm.
    """
    if len(arr) <= 1:
        return arr
    else:
        mid = len(arr) // 2
        left = arr[:mid]
        right = arr[mid:]
        left = merge_sort(left)
        right = merge_sort(right)
        return merge(left, right)

def merge(left: list, right: list) -> list:
    """
    Merges two sorted lists into a single sorted list.
    """
    result = []
    i, j = 0, 0
    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    result += left[i:]
    result += right[j:]
    return result

# %%
merge_sort([90, 12, 333, 1, 2, 67, 7])
# Out:
# [1, 2, 7, 12, 67, 90, 333]

# %%
def heap_sort(arr: list) -> list:
    """
    An implementation of Heapsort sorting algorithm.
    """
    n = len(arr)

    # Build a max-heap
    for i in range(n // 2 - 1, -1, -1):
        heapify(arr, n, i)

    # Extract elements from the heap one by one
    for i in range(n - 1, 0, -1):
        arr[0], arr[i] = arr[i], arr[0]  # swap
        heapify(arr, i, 0)

def heapify(arr: list, n: int, i: int):
    """
    Heapifies a subtree rooted with node i which is an index in arr. 
    n is the size of the heap.
    """
    largest = i
    left = 2 * i + 1
    right = 2 * i + 2

    if left < n and arr[left] > arr[largest]:
        largest = left

    if right < n and arr[right] > arr[largest]:
        largest = right

    if largest != i:
        arr[i], arr[largest] = arr[largest], arr[i]  # swap
        heapify(arr, n, largest)

# %%
ex_arr = [9, 8, 3, 5, 1, 1, 2, 3]
heap_sort(ex_arr)
ex_arr
# Out:
# [1, 1, 2, 3, 3, 5, 8, 9]

# %%
def insertion_sort(arr):
    """
    Sorts a list using the insertion sort algorithm
    with binary search to find the insertion point.
    """
    for i in range(1, len(arr)):
        key = arr[i]

        # Find the index where the key belongs
        index = binary_search(arr, key, 0, i-1)

        # Move elements greater than key to the right
        for j in range(i, index, -1):
            arr[j] = arr[j-1]
        
        arr[index] = key

def binary_search(arr, key, low, high):
    """
    Finds the index where the key should be inserted using binary search.
    """
    while low <= high:
        mid = (low + high) // 2
        if arr[mid] == key:
            return mid
        elif arr[mid] < key:
            low = mid + 1
        else:
            high = mid - 1
    return low

# %%
ex_arr = [9, 8, 3, 5, 1, 1, 2, 3]
insertion_sort(ex_arr)
ex_arr
# Out:
# [1, 1, 2, 3, 3, 5, 8, 9]

# %%
sample_size = []
for i in range(0, 100, 10):
  sample_size.append(i)

for i in range(100, 1000, 100):
  sample_size.append(i)

for i in range(1000, 10000, 1000):
  sample_size.append(i)

for i in range(10000, 100000, 10000):
  sample_size.append(i)

for i in range(100000, 1000001, 100000):
  sample_size.append(i)

# %%
ellapsed_time = []
for n in sample_size:
  start = t.time()
  quick_sort(arr[:n])
  end = t.time()
  ellapsed_time.append(end-start)

# %%
# plot
fig, ax = plt.subplots()

ax.plot(sample_size, ellapsed_time, linewidth=1.5, color="blue", marker="o", markersize=4.2)
ax.set_xlabel("Array size, n")
ax.set_ylabel("Time, s")
ax.set_title("Quicksort")

plt.show()

# %%
table = PrettyTable()
table.field_names = ["Array size, n"] + sample_size[::3]
table.add_row(["Time, s"] + [round(x, 3) for x in ellapsed_time[::3]])
table
# Out:
# +---------------+-------+-----+-----+-----+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+--------+--------+
# | Array size, n |   0   |  30 |  60 |  90 |  300  |  600  |  900  |  3000 |  6000 |  9000 | 30000 | 60000 | 90000 | 300000 | 600000 | 900000 |
# +---------------+-------+-----+-----+-----+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+--------+--------+
# |    Time, s    | 0.001 | 0.0 | 0.0 | 0.0 | 0.001 | 0.001 | 0.002 | 0.002 | 0.013 | 0.022 | 0.065 | 0.134 | 0.228 | 0.829  | 2.002  | 3.402  |
# +---------------+-------+-----+-----+-----+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+--------+--------+

# %%
ellapsed_time = []
for n in sample_size:
  start = t.time()
  merge_sort(arr[:n])
  end = t.time()
  ellapsed_time.append(end-start)

# %%
fig, ax = plt.subplots()

ax.plot(sample_size, ellapsed_time, linewidth=1.5, color="blue", marker="o", markersize=4.2)
ax.set_xlabel("Array size, n")
ax.set_ylabel("Time, s")
ax.set_title("Merge Sort")

plt.show()

# %%
table = PrettyTable()
table.field_names = ["Array size, n"] + sample_size[::3]
table.add_row(["Time, s"] + [round(x, 3) for x in ellapsed_time[::3]])
table
# Out:
# +---------------+-----+-----+-----+-----+-------+-----+-------+-------+-------+-------+-------+-------+-------+--------+--------+--------+
# | Array size, n |  0  |  30 |  60 |  90 |  300  | 600 |  900  |  3000 |  6000 |  9000 | 30000 | 60000 | 90000 | 300000 | 600000 | 900000 |
# +---------------+-----+-----+-----+-----+-------+-----+-------+-------+-------+-------+-------+-------+-------+--------+--------+--------+
# |    Time, s    | 0.0 | 0.0 | 0.0 | 0.0 | 0.002 | 0.0 | 0.003 | 0.011 | 0.028 | 0.032 | 0.144 | 0.326 |  0.49 | 1.869  | 3.886  | 6.102  |
# +---------------+-----+-----+-----+-----+-------+-----+-------+-------+-------+-------+-------+-------+-------+--------+--------+--------+

# %%
ellapsed_time = []
for n in sample_size:
  start = t.time()
  heap_sort(arr[:n])
  end = t.time()
  ellapsed_time.append(end-start)

# %%
fig, ax = plt.subplots()

ax.plot(sample_size, ellapsed_time, linewidth=1.5, color="blue", marker="o", markersize=4.2)
ax.set_xlabel("Array size, n")
ax.set_ylabel("Time, s")
ax.set_title("Heapsort")

plt.show()

# %%
table = PrettyTable()
table.field_names = ["Array size, n"] + sample_size[::3]
table.add_row(["Time, s"] + [round(x, 3) for x in ellapsed_time[::3]])
table
# Out:
# +---------------+-----+-----+-------+-----+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+--------+--------+
# | Array size, n |  0  |  30 |   60  |  90 |  300  |  600  |  900  |  3000 |  6000 |  9000 | 30000 | 60000 | 90000 | 300000 | 600000 | 900000 |
# +---------------+-----+-----+-------+-----+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+--------+--------+
# |    Time, s    | 0.0 | 0.0 | 0.001 | 0.0 | 0.003 | 0.013 | 0.013 | 0.021 | 0.041 | 0.084 | 0.267 |  0.56 | 0.931 | 3.707  |  8.48  | 13.12  |
# +---------------+-----+-----+-------+-----+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+--------+--------+

# %%
ellapsed_time = []
for n in sample_size[:35]:
  start = t.time()
  insertion_sort(arr[:n])
  end = t.time()
  ellapsed_time.append(end-start)

# %%
fig, ax = plt.subplots()

ax.plot(sample_size[:35], ellapsed_time, linewidth=1.5, color="blue", marker="o", markersize=4.2)
ax.set_xlabel("Array size, n")
ax.set_ylabel("Time, s")
ax.set_title("Insertion Sort with Binary Search")

plt.show()

# %%
table = PrettyTable()
table.field_names = ["Array size, n"] + sample_size[:35:2]
table.add_row(["Time, s"] + [round(x, 3) for x in ellapsed_time[::2]])
table
# Out:
# +---------------+-----+-----+-----+-----+-------+-----+-------+-------+------+-------+-------+-------+-------+------+-------+--------+--------+-------+
# | Array size, n |  0  |  20 |  40 |  60 |   80  | 100 |  300  |  500  | 700  |  900  |  2000 |  4000 |  6000 | 8000 | 10000 | 30000  | 50000  | 70000 |
# +---------------+-----+-----+-----+-----+-------+-----+-------+-------+------+-------+-------+-------+-------+------+-------+--------+--------+-------+
# |    Time, s    | 0.0 | 0.0 | 0.0 | 0.0 | 0.001 | 0.0 | 0.002 | 0.005 | 0.01 | 0.017 | 0.076 | 0.311 | 0.719 | 1.21 | 1.876 | 16.545 | 47.458 | 93.44 |
# +---------------+-----+-----+-----+-----+-------+-----+-------+-------+------+-------+-------+-------+-------+------+-------+--------+--------+-------+
